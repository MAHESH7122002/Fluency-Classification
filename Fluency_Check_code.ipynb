# %% [markdown]
# ### Audio Feature Extraction

# %%
import glob
import os
import librosa
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import specgram
import soundfile as sf

##Return audio features
def feature_extraction(file_name):
    X , sample_rate = librosa.load(file_name, sr=None) #Can also load file using librosa
    if X.ndim > 1: # ndim id number of array dimensions
        X = X[:,0]
    X = X.T

    ## stFourier Transform
    stft = np.abs(librosa.stft(X))

    mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=20).T, axis=0) #Returns N_mel coefs
    rmse = np.mean(librosa.feature.rms(y=X).T, axis=0) #RMS Energy for each Frame (Stanford's). Returns 1 value
    spectral_flux = np.mean(librosa.onset.onset_strength(y=X, sr=sample_rate).T, axis=0) #Spectral Flux (Stanford's). Returns 1 Value
    zcr = np.mean(librosa.feature.zero_crossing_rate(y=X).T, axis=0) #Returns 1 value

    #mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0) #Returns 128 values
    #chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T, axis=0) #Returns 12 values
    #contrast = np.mean(librosa.feature.spectral_contrast(S=stft, sr=sample_rate).T, axis=0) #Returns 7 values
    #tonnetz = np.mean(librosa.feature.tonnetz(y=librosa.effects.harmonic(X), sr=sample_rate).T, axis=0) #tonal centroid features Returns 6 values

    ##Return computed audio features
    return mfccs, rmse, spectral_flux, zcr


# Audio parsing: Function makes call for feature extraction and returns array with features and labels
def parse_audio_files(parent_dir, sub_dirs, file_ext='*.mp3'): # Audio Format

    n_mfccs = 20 # This variable is tunneable with each run
    number_of_features = 3 + n_mfccs
    #number_of_features = 154 + n_mfccs # 154 are the total values returned by rest of computed features
    features, labels = np.empty((0,number_of_features)), np.empty(0)

    ##Extract features for each audio file
    for label, sub_dir in enumerate(sub_dirs): ##The enumerate() function adds a counter to an iterable.
        for file_name in glob.glob(os.path.join(parent_dir, sub_dir, file_ext)): #parent is data, sub_dirs are the classes
            print("Actual File Name: ", file_name)
            try:
                mfccs, rmse, spectral_flux, zcr = feature_extraction(file_name)
                #mfccs, zcr, mel, chroma, contrast, tonnetz = feature_extraction(file_name)
            except Exception as e:#if an exception ids found
                print("[Error] there was an error in feature extraction. %s" % (e))
                continue

            extracted_features = np.hstack([mfccs, rmse, spectral_flux, zcr])
            #print "Total Extracted Features: ", len(extracted_features) #This helps us identify really how many features are being computed
            features = np.vstack([features, extracted_features]) #Stack arrays in sequence vertically (row wise).
            labels = np.append(labels, label)
        print("Extracted features from %s, done" % (sub_dir))
    return np.array(features), np.array(labels, dtype = np.int) ## arrays with features and corresponding labels for each audio


# Audio parsing: Function makes call for feature extraction and returns array with features and labels
def audio_data_2d_predict(path, file_ext='*.mp3'): # Audio Format

    file_name = path

    n_mfccs = 20 # This variable is tunneable with each run
    number_of_features = 3 + n_mfccs
    #number_of_features = 154 + n_mfccs # 154 are the total values returned by rest of computed features
    features, labels = np.empty((0,number_of_features)), np.empty(0)

    ##Extract features for each audio file

    mfccs, rmse, spectral_flux, zcr = feature_extraction(file_name)

    extracted_features = np.hstack([mfccs, rmse, spectral_flux, zcr])
            #print "Total Extracted Features: ", len(extracted_features) #This helps us identify really how many features are being computed
    features = np.vstack([features, extracted_features]) #Stack arrays in sequence vertically (row wise).

    return np.array(features)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Read audio classes directories
import os
audio_subdirectories = os.listdir(r'/content/drive/MyDrive/audio files')
audio_subdirectories.sort()
print('Audio Subdirs: ', audio_subdirectories)
# Out:
# Audio Subdirs:  ['001 - Low', '002 - Intermediate', '003 - High']

# %%
import os
os.getcwd()
# Out:
# '/content'

# %% [raw]
# pip install --upgrade librosa

# %%
##Get features and labels
#NumPy array files are created. Files are binary files to store numpy arrays

# Parse Audio Files Function Call
features, labels = parse_audio_files(r'/content/drive/MyDrive/audio files', audio_subdirectories) #(parent dir,sub dirs)
np.save('feat.npy', features)
np.save('label.npy', labels)
# Out:
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 108 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 113 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 103 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 114 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 110 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 102 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 11 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 104 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 1 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 111 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 10 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 31 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 125 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 32 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 116 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 34 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 26 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 13 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 21 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 119 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 30 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 2 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 24 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 37 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 18 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 15 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 118 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 36 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 123 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 115 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 117 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 120 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 122 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 46 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 56 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 64 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 53 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 62 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 47 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 40 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 65 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 39 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 60 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 51 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 42 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 41 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 59 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 5 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 63 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 4 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 45 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 66 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 58 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 74 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 92 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 7 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 91 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 69 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 80 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 8 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 83 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 76 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 87 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 82 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 72 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 79 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 93 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 84 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 75 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 73 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 9 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 81 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 70 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 86 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 85 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 18 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 28 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 94 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 20 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 96 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 27 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 99 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 26 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 98 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 17 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 97 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 24 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 10 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 29 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 14 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 25 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 12 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 95 - D.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 13 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 23 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 48 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 4 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 59 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 33 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 47 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 55 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 51 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 58 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 45 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 34 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 37 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 35 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 56 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 5 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 41 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 57 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 46 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 32 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 54 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 42 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 40 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 103.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 105.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 66 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 101.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 67 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 60 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 100.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 106.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 6 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 8 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 65 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 62 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 1.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 109.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 107.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 102.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 11.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 104.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 10.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Itzel and Friend segment 7 - I.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 108.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 12.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 120.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 122.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 125.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 123.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 116.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 121.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 119.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 112.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 117.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 114.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 124.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 113.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 118.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 111.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 127.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 129.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 128.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 126.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 115.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 110.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 20.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 21.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 25.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 19.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 15.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 133.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 18.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 16.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 131.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 23.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 134.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 22.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 13.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 17.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 26.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 14.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 132.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 27.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 2.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 24.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 130.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 32.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 35.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 38.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 29.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 30.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 39.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 36.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 43.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 47.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 37.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 42.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 45.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 28.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 41.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 46.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 33.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 34.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 3.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 44.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 4.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 40.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 31.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 50.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 6.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 60.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 55.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 54.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 49.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 59.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 65.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 56.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 61.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 64.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 48.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 51.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 62.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 53.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 5.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 63.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 58.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 57.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 52.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 68.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 80.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 67.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 75.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 79.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 8.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 78.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 77.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 72.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 7.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 82.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 66.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 71.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 74.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 70.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 73.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 83.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 81.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 76.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 69.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 92.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 85.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 98.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 95.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 89.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 94.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 86.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 103 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 1 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 97.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 91.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 90.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 88.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 96.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 99.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 9.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 87.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 100 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 84.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Victor and Abraham segment 93.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 26 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 29 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 20 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 113 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 116 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 119 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 12 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 106 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 25 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 28 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 17 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 15 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 22 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 110 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 27 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 109 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 105 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 111 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 19 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 114 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 42 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 31 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 49 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 46 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 45 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 33 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 53 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 51 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 47 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 34 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 35 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 48 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 52 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 3 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 50 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 5 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 44 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 30 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 38 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 6 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 68 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 71 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 67 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 80 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 84 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 74 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 57 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 55 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 59 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 90 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 78 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 8 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 56 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 58 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 73 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 66 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 65 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 7 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 77 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 20 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 21 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 12 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 26 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 28 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 25 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 30 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 31 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 10 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 23 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 91 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 18 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 24 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 98 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 11 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 29 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 27 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 22 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 19 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Avalinguo - Xoca and Josu├⌐ segment 92 - J.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 40 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 47 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 50 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 57 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 48 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 51 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 35 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 49 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 45 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 5 - Elder.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 52 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 53 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 55 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 46 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 56 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 54 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 38 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 36 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 32 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 37 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 39 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 62 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 72 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 9 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 71 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 58 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 70 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 7 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 66 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 67 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 64 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 6 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 59 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 60 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 74 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 61 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 65 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 8 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 73 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 69 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Elderly Chinese street cleaner speaks fluent English segment 68 - E.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 13 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 21 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 35 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 17 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 20 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 23 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 16 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 39 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 31 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 43 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 14 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 38 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 22 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 37 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 30 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 18 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 29 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 15 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 34 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 28 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 24 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 32 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 59 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 62 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 64 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 5 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 50 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 54 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 57 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 58 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 51 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 48 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 47 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 6 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 53 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 44 - W.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/001 - Low/Interview with a Filippines Woman segment 66 - W.mp3
# ...
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 196.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 192.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 189.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 2.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 190.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 191.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 197.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 186.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 199.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 184.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 19.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 187.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 185.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 211.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 217.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 205.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 207.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 203.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 216.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 206.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 201.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 214.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 209.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 212.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 21.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 202.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 215.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 208.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 204.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 213.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 210.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 225.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 232.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 229.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 223.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 222.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 227.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 224.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 220.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 218.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 230.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 231.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 221.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 219.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 22.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 23.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 228.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 226.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 233.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 25.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 240.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 242.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 31.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 28.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 241.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 237.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 26.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 27.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 239.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 3.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 238.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 29.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 235.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 30.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 24.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 236.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 234.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 243.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 45.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 33.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 34.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 42.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 43.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 35.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 4.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 5.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 38.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 37.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 48.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 41.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 47.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 39.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 32.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 46.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 51.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 36.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 49.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 50.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 40.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 44.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 66.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 64.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 56.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 65.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 68.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 69.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 57.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 67.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 54.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 7.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 70.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 6.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 61.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 60.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 63.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 58.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 52.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 62.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 53.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 55.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 59.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 86.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 82.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 89.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 76.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 75.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 87.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 73.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 84.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 8.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 72.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 81.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 88.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 78.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 9.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 80.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 83.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 79.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 74.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 77.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 85.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 71.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 99.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 91.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 95.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 98.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 97.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 96.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 92.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 93.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 94.mp3
# Actual File Name:  /content/drive/MyDrive/audio files/003 - High/Wonderful Abstract Notions segment 90.mp3
# Extracted features from 003 - High, done
# <ipython-input-1-1eb6edf7d723>:57: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return np.array(features), np.array(labels, dtype = np.int) ## arrays with features and corresponding labels for each audio

# %% [markdown]
# features

# %%
len(features)
# Out:
# 1424

# %% [markdown]
# ### Data Exploration

# %%
# THIS STEP IS FOR DATA VISUALIZATION: Label integer encoding
labels = np.load('label.npy') #10 labels total
#print(labels)

# For future label de-encoding
label_classes = np.array(['Low','Intermediate','High'])
#print(label_classes)

# %%
#Load np files
import numpy as np
features= np.load('feat.npy')
#Pandas dataframe with N features for each audio
import pandas as pd
df = pd.DataFrame(features)
df.head()
# Out:
#            0           1          2          3          4          5   \
# 0 -398.888367  119.209305 -15.754964  30.500803   7.324160  33.234371
# 1 -370.214966  125.274338 -10.877201  42.916073  12.611770  25.022348
# 2 -349.058075  138.200989  -9.252151  18.390230   3.433345  24.776398
# 3 -372.404449  138.571976   6.954770  23.988163  18.455238  25.516804
# 4 -379.565094  127.331116 -18.834780  33.835239  14.796187  35.306725
#
#          6         7          8          9   ...         13        14  \
# 0 -5.997307  9.560528   7.400544  -5.151423  ...  -7.739731  7.368675
# 1 -1.545662  5.651212  11.967736  -2.871307  ...  -5.380667  4.189500
# 2 -9.859361  0.649310  18.059729 -10.860069  ... -11.196914  4.234128
# 3  5.041399  7.510303   6.990092  -0.899809  ...  -3.097923  4.250242
# 4 -8.642796  3.337053  10.428965 -12.029839  ... -13.172441  5.990483
#
#          15        16        17        18         19        20        21  \
# 0 -5.922699  0.906328  4.239848 -4.147334  -6.831007  0.029244  1.307984
# 1 -3.843952 -0.785604  5.991245  1.150221  -4.602407  0.038825  1.235302
# 2 -3.006393 -8.180464  3.040962 -0.935617 -10.891191  0.049218  1.261122
# 3 -2.766298  0.848544  4.753158 -1.851380  -5.401827  0.044182  1.279945
# 4 -5.920307 -3.935919  9.047798 -4.899504  -9.925118  0.036989  1.272595
#
#          22
# 0  0.065530
# 1  0.038756
# 2  0.054952
# 3  0.037937
# 4  0.058060
#
# [5 rows x 23 columns]

# %% [markdown]
# #### Visualize the MFCC series

# %%
import matplotlib.pyplot as plt
import librosa.display
plt.figure(figsize=(10, 6))
librosa.display.specshow(features, x_axis='time')
plt.colorbar()
plt.title('MFCCs = 5 Values for 5s Audio Frames (High Class)')
plt.tight_layout()
plt.savefig('test saving.png')
#Correct Interpretation of MFCC Spectrograms??: https://dsp.stackexchange.com/questions/38830/whats-the-correct-graphical-interpretation-of-a-series-of-mfcc-vectors

# %%
features.shape #1424 Frames (Segments), 5 MFCCs
len(features[1])
# Out:
# 23

# %% [markdown]
# #### Plot of spectrograms using Librosa module
# - Reference: https://librosa.github.io/librosa/generated/librosa.display.specshow.html

# %%
#Visualize an STFT power spectrum
import matplotlib.pyplot as plt
y , sr = librosa.load(r'/content/drive/MyDrive/voice_clone/my_voice.mp3', sr=None) # Using my own audio segment
#y, sr = librosa.load(librosa.util.example_audio_file())
plt.figure(figsize=(20, 15))
D = librosa.amplitude_to_db(librosa.stft(y), ref=np.max) #Convert amplitude into db
plt.subplot(4, 2, 1)
librosa.display.specshow(D, y_axis='linear') #Linear Scale
plt.colorbar(format='%+2.0f dB')
plt.title('Linear-frequency power spectrogram')

# The above one on a logarithmic scale
plt.subplot(4, 2, 2)
#plt.figure(figsize=(20, 10))
librosa.display.specshow(D, y_axis='log') #Log scale
plt.colorbar(format='%+2.0f dB')
plt.title('Log-frequency power spectrogram')

# Draw a chromagram with pitch classes
C = librosa.feature.chroma_cqt(y=y, sr=sr)
plt.subplot(4, 2, 3)
librosa.display.specshow(C, y_axis='chroma')
plt.colorbar()
plt.title('Chromagram')

#Force a grayscale colormap (white -> black)
plt.subplot(4, 2, 4)
librosa.display.specshow(D, cmap='gray_r', y_axis='linear')
plt.colorbar(format='%+2.0f dB')
plt.title('Linear power spectrogram (grayscale)')
# Out:
# <ipython-input-11-2bddf0ce4ea3>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y , sr = librosa.load(r'/content/drive/MyDrive/voice_clone/my_voice.mp3', sr=None) # Using my own audio segment
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# <ipython-input-11-2bddf0ce4ea3>:6: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   D = librosa.amplitude_to_db(librosa.stft(y), ref=np.max) #Convert amplitude into db
# Text(0.5, 1.0, 'Linear power spectrogram (grayscale)')

# %% [markdown]
# ### Multilayer Perceptron (MLP) for multi-class softmax classification (Keras Tensorflow)

# %%
# coding= UTF-8
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import SGD
from sklearn.model_selection import train_test_split

# Fix random seed number
np.random.seed(7)

# Load the data
X = np.load('feat.npy')
y = np.load('label.npy').ravel() #Return a contiguous flattened array.

number_of_features = len(X[1]) #This is variable with each run
number_of_classes = 3

# Sample data randomly
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0) #70% Train, 30% Test

# Neural Network Architecture
mlp = Sequential() # Define Sequential model

# Using relu on the first two layers and softmax on the output layer

# 1st Layer
#N neurons, Number_Fatures-dimensional vectors
mlp.add(Dense(512, input_dim=number_of_features, activation='relu')) #32, 64, 128, 256, 512, 1024
mlp.add(Dropout(0.5))

# 2nd Layer
mlp.add(Dense(512, activation='relu'))
mlp.add(Dropout(0.5))

# 3rd Layer. Output 3 neurons corresponding the number of classes
# The sigmoid function is used for the two-class logistic regression,
# whereas the softmax function is used for the multiclass logistic regression
mlp.add(Dense(number_of_classes, activation='softmax'))

# Model Compilation. Loss for multi-class classification problem
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
rmsprop = 'rmsprop'
adam = 'adam'
mlp.compile(loss='categorical_crossentropy',
              optimizer= rmsprop, #rmsprop better than sgd
              metrics=['accuracy'])

# Convert labels to categorical one-hot encoding
y_train = keras.utils.to_categorical(y_train-1, num_classes= number_of_classes) # Convert class vector into binary Matrix
y_test = keras.utils.to_categorical(y_test-1, num_classes= number_of_classes)

# Train and test
mlp.fit(X_train, y_train, epochs=300, batch_size=64) #batch 32, 64, 128, 256, 512
score, acc = mlp.evaluate(X_test, y_test, batch_size=64)
# Out:
# Epoch 1/300
# /usr/local/lib/python3.10/dist-packages/keras/optimizers/legacy/gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 16/16 [==============================] - 1s 10ms/step - loss: 26.5141 - accuracy: 0.3946
# Epoch 2/300
# 16/16 [==============================] - 0s 9ms/step - loss: 9.3291 - accuracy: 0.4930
# Epoch 3/300
# 16/16 [==============================] - 0s 9ms/step - loss: 6.8453 - accuracy: 0.4980
# Epoch 4/300
# 16/16 [==============================] - 0s 9ms/step - loss: 4.1727 - accuracy: 0.5351
# Epoch 5/300
# 16/16 [==============================] - 0s 9ms/step - loss: 2.5888 - accuracy: 0.5653
# Epoch 6/300
# 16/16 [==============================] - 0s 8ms/step - loss: 1.7655 - accuracy: 0.6165
# Epoch 7/300
# 16/16 [==============================] - 0s 9ms/step - loss: 1.4023 - accuracy: 0.6185
# Epoch 8/300
# 16/16 [==============================] - 0s 9ms/step - loss: 1.0072 - accuracy: 0.6516
# Epoch 9/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.9161 - accuracy: 0.6737
# Epoch 10/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.8106 - accuracy: 0.6898
# Epoch 11/300
# 16/16 [==============================] - 0s 8ms/step - loss: 0.7453 - accuracy: 0.7279
# Epoch 12/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.6980 - accuracy: 0.7329
# Epoch 13/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.6449 - accuracy: 0.7460
# Epoch 14/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.6307 - accuracy: 0.7400
# Epoch 15/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.5549 - accuracy: 0.7942
# Epoch 16/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.5296 - accuracy: 0.7912
# Epoch 17/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.5395 - accuracy: 0.7831
# Epoch 18/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.5105 - accuracy: 0.7982
# Epoch 19/300
# 16/16 [==============================] - 0s 8ms/step - loss: 0.5020 - accuracy: 0.8032
# Epoch 20/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.4474 - accuracy: 0.8273
# Epoch 21/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.4582 - accuracy: 0.8133
# Epoch 22/300
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4364 - accuracy: 0.8233
# Epoch 23/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4527 - accuracy: 0.8243
# Epoch 24/300
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4367 - accuracy: 0.8303
# Epoch 25/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.4248 - accuracy: 0.8313
# Epoch 26/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3766 - accuracy: 0.8434
# Epoch 27/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3651 - accuracy: 0.8424
# Epoch 28/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3427 - accuracy: 0.8665
# Epoch 29/300
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3779 - accuracy: 0.8464
# Epoch 30/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3565 - accuracy: 0.8594
# Epoch 31/300
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3206 - accuracy: 0.8655
# Epoch 32/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3045 - accuracy: 0.8554
# Epoch 33/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3520 - accuracy: 0.8604
# Epoch 34/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3561 - accuracy: 0.8574
# Epoch 35/300
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3049 - accuracy: 0.8815
# Epoch 36/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.2647 - accuracy: 0.8785
# Epoch 37/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.2768 - accuracy: 0.8896
# Epoch 38/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3051 - accuracy: 0.8635
# Epoch 39/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.2604 - accuracy: 0.8835
# Epoch 40/300
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3131 - accuracy: 0.8825
# Epoch 41/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.2729 - accuracy: 0.8845
# Epoch 42/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.2656 - accuracy: 0.8865
# Epoch 43/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.2701 - accuracy: 0.8926
# Epoch 44/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.2610 - accuracy: 0.8896
# Epoch 45/300
# 16/16 [==============================] - 0s 8ms/step - loss: 0.2413 - accuracy: 0.8926
# Epoch 46/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.2681 - accuracy: 0.8906
# Epoch 47/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.2973 - accuracy: 0.8785
# Epoch 48/300
# 16/16 [==============================] - 0s 8ms/step - loss: 0.2399 - accuracy: 0.8996
# Epoch 49/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.2573 - accuracy: 0.8906
# Epoch 50/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.2429 - accuracy: 0.8896
# Epoch 51/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.2388 - accuracy: 0.9046
# Epoch 52/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.2344 - accuracy: 0.8906
# Epoch 53/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.2216 - accuracy: 0.9116
# Epoch 54/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.2497 - accuracy: 0.8956
# Epoch 55/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.2554 - accuracy: 0.8966
# Epoch 56/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.2238 - accuracy: 0.9106
# Epoch 57/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.2299 - accuracy: 0.8976
# Epoch 58/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.2212 - accuracy: 0.9036
# Epoch 59/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.2366 - accuracy: 0.9036
# Epoch 60/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.2223 - accuracy: 0.8986
# Epoch 61/300
# 16/16 [==============================] - 0s 13ms/step - loss: 0.2303 - accuracy: 0.8936
# Epoch 62/300
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1740 - accuracy: 0.9187
# Epoch 63/300
# 16/16 [==============================] - 0s 13ms/step - loss: 0.2081 - accuracy: 0.9066
# Epoch 64/300
# 16/16 [==============================] - 0s 14ms/step - loss: 0.2221 - accuracy: 0.9036
# Epoch 65/300
# 16/16 [==============================] - 0s 13ms/step - loss: 0.2119 - accuracy: 0.9177
# Epoch 66/300
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1839 - accuracy: 0.9237
# Epoch 67/300
# 16/16 [==============================] - 0s 13ms/step - loss: 0.2358 - accuracy: 0.9086
# Epoch 68/300
# 16/16 [==============================] - 0s 14ms/step - loss: 0.2133 - accuracy: 0.9157
# Epoch 69/300
# 16/16 [==============================] - 0s 13ms/step - loss: 0.2261 - accuracy: 0.9106
# Epoch 70/300
# 16/16 [==============================] - 0s 14ms/step - loss: 0.2112 - accuracy: 0.9026
# Epoch 71/300
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1923 - accuracy: 0.9147
# Epoch 72/300
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1933 - accuracy: 0.9177
# Epoch 73/300
# 16/16 [==============================] - 0s 13ms/step - loss: 0.2379 - accuracy: 0.9137
# Epoch 74/300
# 16/16 [==============================] - 0s 14ms/step - loss: 0.2070 - accuracy: 0.9106
# Epoch 75/300
# 16/16 [==============================] - 0s 13ms/step - loss: 0.2036 - accuracy: 0.9076
# Epoch 76/300
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1729 - accuracy: 0.9187
# Epoch 77/300
# 16/16 [==============================] - 0s 14ms/step - loss: 0.2043 - accuracy: 0.9116
# Epoch 78/300
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1825 - accuracy: 0.9247
# Epoch 79/300
# 16/16 [==============================] - 0s 13ms/step - loss: 0.2307 - accuracy: 0.9207
# Epoch 80/300
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1621 - accuracy: 0.9327
# Epoch 81/300
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1725 - accuracy: 0.9197
# Epoch 82/300
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1957 - accuracy: 0.9137
# Epoch 83/300
# 16/16 [==============================] - 0s 13ms/step - loss: 0.2118 - accuracy: 0.9086
# Epoch 84/300
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1617 - accuracy: 0.9317
# Epoch 85/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1826 - accuracy: 0.9187
# Epoch 86/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1770 - accuracy: 0.9167
# Epoch 87/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1829 - accuracy: 0.9267
# Epoch 88/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1830 - accuracy: 0.9197
# Epoch 89/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.2294 - accuracy: 0.9217
# Epoch 90/300
# 16/16 [==============================] - 0s 8ms/step - loss: 0.1763 - accuracy: 0.9177
# Epoch 91/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1708 - accuracy: 0.9237
# Epoch 92/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1576 - accuracy: 0.9357
# Epoch 93/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1627 - accuracy: 0.9257
# Epoch 94/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1633 - accuracy: 0.9327
# Epoch 95/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1671 - accuracy: 0.9257
# Epoch 96/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1724 - accuracy: 0.9197
# Epoch 97/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1586 - accuracy: 0.9287
# Epoch 98/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1986 - accuracy: 0.9257
# Epoch 99/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1446 - accuracy: 0.9357
# Epoch 100/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1856 - accuracy: 0.9187
# Epoch 101/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1782 - accuracy: 0.9127
# Epoch 102/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1413 - accuracy: 0.9388
# Epoch 103/300
# 16/16 [==============================] - 0s 8ms/step - loss: 0.1890 - accuracy: 0.9287
# Epoch 104/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1718 - accuracy: 0.9267
# Epoch 105/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1882 - accuracy: 0.9237
# Epoch 106/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1911 - accuracy: 0.9287
# Epoch 107/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1406 - accuracy: 0.9317
# Epoch 108/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1645 - accuracy: 0.9337
# Epoch 109/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1789 - accuracy: 0.9287
# Epoch 110/300
# 16/16 [==============================] - 0s 8ms/step - loss: 0.1626 - accuracy: 0.9418
# Epoch 111/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1683 - accuracy: 0.9378
# Epoch 112/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1285 - accuracy: 0.9398
# Epoch 113/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1533 - accuracy: 0.9267
# Epoch 114/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1548 - accuracy: 0.9297
# Epoch 115/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1815 - accuracy: 0.9287
# Epoch 116/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1469 - accuracy: 0.9357
# Epoch 117/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1661 - accuracy: 0.9307
# Epoch 118/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1586 - accuracy: 0.9277
# Epoch 119/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1493 - accuracy: 0.9347
# Epoch 120/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1524 - accuracy: 0.9297
# Epoch 121/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1559 - accuracy: 0.9267
# Epoch 122/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1500 - accuracy: 0.9418
# Epoch 123/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1549 - accuracy: 0.9347
# Epoch 124/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1388 - accuracy: 0.9337
# Epoch 125/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1347 - accuracy: 0.9398
# Epoch 126/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1433 - accuracy: 0.9398
# Epoch 127/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1445 - accuracy: 0.9367
# Epoch 128/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1255 - accuracy: 0.9478
# Epoch 129/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1534 - accuracy: 0.9287
# Epoch 130/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1475 - accuracy: 0.9408
# Epoch 131/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1387 - accuracy: 0.9337
# Epoch 132/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1407 - accuracy: 0.9448
# Epoch 133/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1234 - accuracy: 0.9458
# Epoch 134/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1346 - accuracy: 0.9448
# Epoch 135/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1454 - accuracy: 0.9337
# Epoch 136/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1571 - accuracy: 0.9367
# Epoch 137/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1490 - accuracy: 0.9337
# Epoch 138/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1181 - accuracy: 0.9438
# Epoch 139/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1509 - accuracy: 0.9458
# Epoch 140/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1681 - accuracy: 0.9317
# Epoch 141/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1309 - accuracy: 0.9428
# Epoch 142/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1384 - accuracy: 0.9458
# Epoch 143/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1388 - accuracy: 0.9388
# Epoch 144/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1581 - accuracy: 0.9297
# Epoch 145/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1704 - accuracy: 0.9418
# Epoch 146/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1278 - accuracy: 0.9367
# Epoch 147/300
# 16/16 [==============================] - 0s 8ms/step - loss: 0.1370 - accuracy: 0.9408
# Epoch 148/300
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1485 - accuracy: 0.9448
# Epoch 149/300
# 16/16 [==============================] - 0s 21ms/step - loss: 0.1390 - accuracy: 0.9438
# Epoch 150/300
# 16/16 [==============================] - 0s 23ms/step - loss: 0.1435 - accuracy: 0.9438
# Epoch 151/300
# 16/16 [==============================] - 0s 18ms/step - loss: 0.1382 - accuracy: 0.9388
# Epoch 152/300
# 16/16 [==============================] - 0s 21ms/step - loss: 0.1234 - accuracy: 0.9448
# Epoch 153/300
# 16/16 [==============================] - 0s 21ms/step - loss: 0.1396 - accuracy: 0.9438
# Epoch 154/300
# 16/16 [==============================] - 0s 21ms/step - loss: 0.1448 - accuracy: 0.9418
# Epoch 155/300
# 16/16 [==============================] - 0s 17ms/step - loss: 0.1185 - accuracy: 0.9538
# Epoch 156/300
# 16/16 [==============================] - 0s 17ms/step - loss: 0.1259 - accuracy: 0.9518
# Epoch 157/300
# 16/16 [==============================] - 0s 25ms/step - loss: 0.1321 - accuracy: 0.9418
# Epoch 158/300
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1337 - accuracy: 0.9398
# Epoch 159/300
# 16/16 [==============================] - 0s 19ms/step - loss: 0.1301 - accuracy: 0.9528
# Epoch 160/300
# 16/16 [==============================] - 0s 16ms/step - loss: 0.1510 - accuracy: 0.9388
# Epoch 161/300
# 16/16 [==============================] - 0s 22ms/step - loss: 0.1177 - accuracy: 0.9468
# Epoch 162/300
# 16/16 [==============================] - 0s 21ms/step - loss: 0.1328 - accuracy: 0.9458
# Epoch 163/300
# 16/16 [==============================] - 0s 20ms/step - loss: 0.1339 - accuracy: 0.9448
# Epoch 164/300
# 16/16 [==============================] - 0s 19ms/step - loss: 0.1713 - accuracy: 0.9378
# Epoch 165/300
# 16/16 [==============================] - 0s 21ms/step - loss: 0.1328 - accuracy: 0.9408
# Epoch 166/300
# 16/16 [==============================] - 0s 23ms/step - loss: 0.1274 - accuracy: 0.9468
# Epoch 167/300
# 16/16 [==============================] - 0s 17ms/step - loss: 0.1206 - accuracy: 0.9458
# Epoch 168/300
# 16/16 [==============================] - 0s 18ms/step - loss: 0.1193 - accuracy: 0.9478
# Epoch 169/300
# 16/16 [==============================] - 0s 18ms/step - loss: 0.1385 - accuracy: 0.9337
# Epoch 170/300
# 16/16 [==============================] - 0s 17ms/step - loss: 0.1338 - accuracy: 0.9478
# Epoch 171/300
# 16/16 [==============================] - 0s 18ms/step - loss: 0.1517 - accuracy: 0.9438
# Epoch 172/300
# 16/16 [==============================] - 0s 17ms/step - loss: 0.1394 - accuracy: 0.9408
# Epoch 173/300
# 16/16 [==============================] - 0s 17ms/step - loss: 0.1077 - accuracy: 0.9538
# Epoch 174/300
# 16/16 [==============================] - 0s 17ms/step - loss: 0.1411 - accuracy: 0.9378
# Epoch 175/300
# 16/16 [==============================] - 0s 17ms/step - loss: 0.1144 - accuracy: 0.9458
# Epoch 176/300
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1170 - accuracy: 0.9428
# Epoch 177/300
# 16/16 [==============================] - 0s 18ms/step - loss: 0.1444 - accuracy: 0.9468
# Epoch 178/300
# 16/16 [==============================] - 0s 21ms/step - loss: 0.1306 - accuracy: 0.9478
# Epoch 179/300
# 16/16 [==============================] - 0s 20ms/step - loss: 0.1309 - accuracy: 0.9378
# Epoch 180/300
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1492 - accuracy: 0.9428
# Epoch 181/300
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1378 - accuracy: 0.9478
# Epoch 182/300
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1180 - accuracy: 0.9448
# Epoch 183/300
# 16/16 [==============================] - 0s 15ms/step - loss: 0.1102 - accuracy: 0.9558
# Epoch 184/300
# 16/16 [==============================] - 0s 16ms/step - loss: 0.1198 - accuracy: 0.9498
# Epoch 185/300
# 16/16 [==============================] - 0s 18ms/step - loss: 0.1210 - accuracy: 0.9468
# Epoch 186/300
# 16/16 [==============================] - 0s 15ms/step - loss: 0.1105 - accuracy: 0.9518
# Epoch 187/300
# 16/16 [==============================] - 0s 17ms/step - loss: 0.1129 - accuracy: 0.9558
# Epoch 188/300
# 16/16 [==============================] - 0s 16ms/step - loss: 0.1292 - accuracy: 0.9378
# Epoch 189/300
# 16/16 [==============================] - 0s 15ms/step - loss: 0.1329 - accuracy: 0.9398
# Epoch 190/300
# 16/16 [==============================] - 0s 17ms/step - loss: 0.1357 - accuracy: 0.9438
# Epoch 191/300
# 16/16 [==============================] - 0s 15ms/step - loss: 0.1234 - accuracy: 0.9378
# Epoch 192/300
# 16/16 [==============================] - 0s 15ms/step - loss: 0.1125 - accuracy: 0.9448
# Epoch 193/300
# 16/16 [==============================] - 0s 16ms/step - loss: 0.1245 - accuracy: 0.9508
# Epoch 194/300
# 16/16 [==============================] - 0s 18ms/step - loss: 0.1289 - accuracy: 0.9418
# Epoch 195/300
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1260 - accuracy: 0.9498
# Epoch 196/300
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1151 - accuracy: 0.9458
# Epoch 197/300
# 16/16 [==============================] - 0s 16ms/step - loss: 0.1493 - accuracy: 0.9367
# Epoch 198/300
# 16/16 [==============================] - 0s 21ms/step - loss: 0.1134 - accuracy: 0.9488
# Epoch 199/300
# 16/16 [==============================] - 0s 17ms/step - loss: 0.1275 - accuracy: 0.9468
# Epoch 200/300
# 16/16 [==============================] - 0s 16ms/step - loss: 0.1250 - accuracy: 0.9488
# Epoch 201/300
# 16/16 [==============================] - 0s 18ms/step - loss: 0.1268 - accuracy: 0.9548
# Epoch 202/300
# 16/16 [==============================] - 0s 17ms/step - loss: 0.1217 - accuracy: 0.9388
# Epoch 203/300
# 16/16 [==============================] - 0s 16ms/step - loss: 0.1162 - accuracy: 0.9508
# Epoch 204/300
# 16/16 [==============================] - 0s 17ms/step - loss: 0.1367 - accuracy: 0.9458
# Epoch 205/300
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1248 - accuracy: 0.9518
# Epoch 206/300
# 16/16 [==============================] - 0s 19ms/step - loss: 0.1211 - accuracy: 0.9488
# Epoch 207/300
# 16/16 [==============================] - 0s 19ms/step - loss: 0.1280 - accuracy: 0.9468
# Epoch 208/300
# 16/16 [==============================] - 0s 21ms/step - loss: 0.1224 - accuracy: 0.9418
# Epoch 209/300
# 16/16 [==============================] - 0s 15ms/step - loss: 0.1123 - accuracy: 0.9508
# Epoch 210/300
# 16/16 [==============================] - 0s 16ms/step - loss: 0.1341 - accuracy: 0.9448
# Epoch 211/300
# 16/16 [==============================] - 0s 16ms/step - loss: 0.1351 - accuracy: 0.9518
# Epoch 212/300
# 16/16 [==============================] - 0s 18ms/step - loss: 0.1155 - accuracy: 0.9518
# Epoch 213/300
# 16/16 [==============================] - 0s 17ms/step - loss: 0.1337 - accuracy: 0.9518
# Epoch 214/300
# 16/16 [==============================] - 0s 18ms/step - loss: 0.1234 - accuracy: 0.9568
# Epoch 215/300
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0985 - accuracy: 0.9598
# Epoch 216/300
# 16/16 [==============================] - 0s 20ms/step - loss: 0.1137 - accuracy: 0.9498
# Epoch 217/300
# 16/16 [==============================] - 0s 22ms/step - loss: 0.1298 - accuracy: 0.9438
# Epoch 218/300
# 16/16 [==============================] - 0s 22ms/step - loss: 0.1308 - accuracy: 0.9528
# Epoch 219/300
# 16/16 [==============================] - 0s 19ms/step - loss: 0.1064 - accuracy: 0.9548
# Epoch 220/300
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0769 - accuracy: 0.9608
# Epoch 221/300
# 16/16 [==============================] - 0s 24ms/step - loss: 0.1184 - accuracy: 0.9528
# Epoch 222/300
# 16/16 [==============================] - 0s 20ms/step - loss: 0.1134 - accuracy: 0.9548
# Epoch 223/300
# 16/16 [==============================] - 0s 18ms/step - loss: 0.1074 - accuracy: 0.9488
# Epoch 224/300
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0969 - accuracy: 0.9588
# Epoch 225/300
# 16/16 [==============================] - 0s 16ms/step - loss: 0.1233 - accuracy: 0.9538
# Epoch 226/300
# 16/16 [==============================] - 0s 18ms/step - loss: 0.1202 - accuracy: 0.9518
# Epoch 227/300
# 16/16 [==============================] - 0s 15ms/step - loss: 0.1075 - accuracy: 0.9428
# Epoch 228/300
# 16/16 [==============================] - 0s 18ms/step - loss: 0.1275 - accuracy: 0.9508
# Epoch 229/300
# 16/16 [==============================] - 0s 19ms/step - loss: 0.1069 - accuracy: 0.9538
# Epoch 230/300
# 16/16 [==============================] - 0s 16ms/step - loss: 0.1101 - accuracy: 0.9508
# Epoch 231/300
# 16/16 [==============================] - 0s 16ms/step - loss: 0.1070 - accuracy: 0.9498
# Epoch 232/300
# 16/16 [==============================] - 0s 17ms/step - loss: 0.1329 - accuracy: 0.9428
# Epoch 233/300
# 16/16 [==============================] - 0s 17ms/step - loss: 0.1122 - accuracy: 0.9508
# Epoch 234/300
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1535 - accuracy: 0.9498
# Epoch 235/300
# 16/16 [==============================] - 0s 16ms/step - loss: 0.1064 - accuracy: 0.9508
# Epoch 236/300
# 16/16 [==============================] - 0s 17ms/step - loss: 0.1029 - accuracy: 0.9558
# Epoch 237/300
# 16/16 [==============================] - 0s 18ms/step - loss: 0.1056 - accuracy: 0.9548
# Epoch 238/300
# 16/16 [==============================] - 0s 17ms/step - loss: 0.1165 - accuracy: 0.9438
# Epoch 239/300
# 16/16 [==============================] - 0s 17ms/step - loss: 0.1241 - accuracy: 0.9498
# Epoch 240/300
# 16/16 [==============================] - 0s 18ms/step - loss: 0.1122 - accuracy: 0.9558
# Epoch 241/300
# 16/16 [==============================] - 0s 15ms/step - loss: 0.1028 - accuracy: 0.9528
# Epoch 242/300
# 16/16 [==============================] - 0s 17ms/step - loss: 0.1071 - accuracy: 0.9608
# Epoch 243/300
# 16/16 [==============================] - 0s 19ms/step - loss: 0.1165 - accuracy: 0.9518
# Epoch 244/300
# 16/16 [==============================] - 0s 18ms/step - loss: 0.1008 - accuracy: 0.9598
# Epoch 245/300
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1242 - accuracy: 0.9508
# Epoch 246/300
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1213 - accuracy: 0.9558
# Epoch 247/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0919 - accuracy: 0.9608
# Epoch 248/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1024 - accuracy: 0.9498
# Epoch 249/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1048 - accuracy: 0.9578
# Epoch 250/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1222 - accuracy: 0.9478
# Epoch 251/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0801 - accuracy: 0.9608
# Epoch 252/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0939 - accuracy: 0.9639
# Epoch 253/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0922 - accuracy: 0.9649
# Epoch 254/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0943 - accuracy: 0.9588
# Epoch 255/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1116 - accuracy: 0.9538
# Epoch 256/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0999 - accuracy: 0.9598
# Epoch 257/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1050 - accuracy: 0.9558
# Epoch 258/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1134 - accuracy: 0.9548
# Epoch 259/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1295 - accuracy: 0.9418
# Epoch 260/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0850 - accuracy: 0.9598
# Epoch 261/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1198 - accuracy: 0.9598
# Epoch 262/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0967 - accuracy: 0.9558
# Epoch 263/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1036 - accuracy: 0.9578
# Epoch 264/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1121 - accuracy: 0.9518
# Epoch 265/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0984 - accuracy: 0.9558
# Epoch 266/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0973 - accuracy: 0.9558
# Epoch 267/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1292 - accuracy: 0.9558
# Epoch 268/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1123 - accuracy: 0.9538
# Epoch 269/300
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1073 - accuracy: 0.9528
# Epoch 270/300
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1033 - accuracy: 0.9568
# Epoch 271/300
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1025 - accuracy: 0.9498
# Epoch 272/300
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1153 - accuracy: 0.9478
# Epoch 273/300
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0985 - accuracy: 0.9578
# Epoch 274/300
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1260 - accuracy: 0.9528
# Epoch 275/300
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1117 - accuracy: 0.9568
# Epoch 276/300
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1175 - accuracy: 0.9558
# Epoch 277/300
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1076 - accuracy: 0.9548
# Epoch 278/300
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1192 - accuracy: 0.9548
# Epoch 279/300
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1250 - accuracy: 0.9508
# Epoch 280/300
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0999 - accuracy: 0.9538
# Epoch 281/300
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0981 - accuracy: 0.9608
# Epoch 282/300
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1077 - accuracy: 0.9649
# Epoch 283/300
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1126 - accuracy: 0.9548
# Epoch 284/300
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1073 - accuracy: 0.9598
# Epoch 285/300
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1058 - accuracy: 0.9518
# Epoch 286/300
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0822 - accuracy: 0.9679
# Epoch 287/300
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0916 - accuracy: 0.9598
# Epoch 288/300
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1071 - accuracy: 0.9578
# Epoch 289/300
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0953 - accuracy: 0.9598
# Epoch 290/300
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1009 - accuracy: 0.9588
# Epoch 291/300
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0949 - accuracy: 0.9558
# Epoch 292/300
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0820 - accuracy: 0.9598
# Epoch 293/300
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0970 - accuracy: 0.9649
# Epoch 294/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1244 - accuracy: 0.9538
# Epoch 295/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1313 - accuracy: 0.9518
# Epoch 296/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1245 - accuracy: 0.9488
# Epoch 297/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0874 - accuracy: 0.9629
# Epoch 298/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0855 - accuracy: 0.9608
# Epoch 299/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1094 - accuracy: 0.9558
# Epoch 300/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1056 - accuracy: 0.9578
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3285 - accuracy: 0.9463

# %%
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# Test score: 0.3284999132156372
# Test accuracy: 0.9462617039680481

# %% [markdown]
# ###Predict

# %%
#@title Listen  Source file.

from IPython.display import Audio,HTML

# HTML code
html = """
<!DOCTYPE html>
<html>
  <head>
    <meta charset="UTF-8">
    <title>Welcome</title>
    <style>
      body {
        font-family: Arial, sans-serif;
        background-color: black;
        margin: 0;
        padding: 0;
        color: white;
      }

      .container {
        width: 100%;
        height: 100%;
        display: flex;
        justify-content: center;
        align-items: center;
      }

      .content {
        display: flex;
        flex-direction: column;
        align-items: center;
        text-align: center;
        max-width: 800px;
      }

      h1 {
        font-size: 4rem;
        color: #00ff00;
        margin-top: 0;
      }

      p {
        font-size: 1.5rem;
        color: grey;
        margin-bottom: 2rem;
      }

    </style>
  </head>
  <body>
    <div class="container">
      <div class="content">
        <h1>Audio File</h1>
        <p>Source File</p>

      </div>
    </div>
  </body>
</html>


"""
display(HTML(html))
Audio('/content/drive/MyDrive/voice_clone/my_voice.mp3')
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="UTF-8">
#     <title>Welcome</title>
#     <style>
#       body {
#         font-family: Arial, sans-serif;
#         background-color: black;
#         margin: 0;
#         padding: 0;
#         color: white;
#       }
#
#       .container {
#         width: 100%;
#         height: 100%;
#         display: flex;
#         justify-content: center;
#         align-items: center;
#       }
#
#       .content {
#         display: flex;
#         flex-direction: column;
#         align-items: center;
#         text-align: center;
#         max-width: 800px;
#       }
#
#       h1 {
#         font-size: 4rem;
#         color: #00ff00;
#         margin-top: 0;
#       }
#
#       p {
#         font-size: 1.5rem;
#         color: grey;
#         margin-bottom: 2rem;
#       }
#
#     </style>
#   </head>
#   <body>
#     <div class="container">
#       <div class="content">
#         <h1>Audio File</h1>
#         <p>Source File</p>
#
#       </div>
#     </div>
#   </body>
# </html>
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa
import matplotlib.pyplot as plt

filename = '/content/drive/MyDrive/audio files/001 - Low/Avalinguo - Dana and Konay segment 1 - D.mp3'
data, sample_rate = librosa.load(filename)

plt.figure(figsize=(14, 5))
plt.plot(data)
plt.title('Waveplot')
plt.xlabel('Time (samples)')
plt.ylabel('Amplitude')
plt.show()

# %%
display(HTML(html))
Audio('/content/drive/MyDrive/audio files/002 - Intermediate/Angela_merkel_speaking_english_to_british_parliament segment 1.mp3')
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="UTF-8">
#     <title>Welcome</title>
#     <style>
#       body {
#         font-family: Arial, sans-serif;
#         background-color: black;
#         margin: 0;
#         padding: 0;
#         color: white;
#       }
#
#       .container {
#         width: 100%;
#         height: 100%;
#         display: flex;
#         justify-content: center;
#         align-items: center;
#       }
#
#       .content {
#         display: flex;
#         flex-direction: column;
#         align-items: center;
#         text-align: center;
#         max-width: 800px;
#       }
#
#       h1 {
#         font-size: 4rem;
#         color: #00ff00;
#         margin-top: 0;
#       }
#
#       p {
#         font-size: 1.5rem;
#         color: grey;
#         margin-bottom: 2rem;
#       }
#
#     </style>
#   </head>
#   <body>
#     <div class="container">
#       <div class="content">
#         <h1>Audio File</h1>
#         <p>Source File</p>
#
#       </div>
#     </div>
#   </body>
# </html>
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa
import matplotlib.pyplot as plt

filename = '/content/drive/MyDrive/audio files/002 - Intermediate/Angela_merkel_speaking_english_to_british_parliament segment 1.mp3'
data, sample_rate = librosa.load(filename)

plt.figure(figsize=(14, 5))
plt.plot(data)
plt.title('Waveplot')
plt.xlabel('Time (samples)')
plt.ylabel('Amplitude')
plt.show()

# %%
display(HTML(html))
Audio('/content/drive/MyDrive/audio files/003 - High/Avalinguo - Alan and Eduardo segment 100 - A.mp3')
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="UTF-8">
#     <title>Welcome</title>
#     <style>
#       body {
#         font-family: Arial, sans-serif;
#         background-color: black;
#         margin: 0;
#         padding: 0;
#         color: white;
#       }
#
#       .container {
#         width: 100%;
#         height: 100%;
#         display: flex;
#         justify-content: center;
#         align-items: center;
#       }
#
#       .content {
#         display: flex;
#         flex-direction: column;
#         align-items: center;
#         text-align: center;
#         max-width: 800px;
#       }
#
#       h1 {
#         font-size: 4rem;
#         color: #00ff00;
#         margin-top: 0;
#       }
#
#       p {
#         font-size: 1.5rem;
#         color: grey;
#         margin-bottom: 2rem;
#       }
#
#     </style>
#   </head>
#   <body>
#     <div class="container">
#       <div class="content">
#         <h1>Audio File</h1>
#         <p>Source File</p>
#
#       </div>
#     </div>
#   </body>
# </html>
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa
import matplotlib.pyplot as plt

filename = '/content/drive/MyDrive/audio files/003 - High/Avalinguo - Alan and Eduardo segment 100 - A.mp3'
data, sample_rate = librosa.load(filename)

plt.figure(figsize=(14, 5))
plt.plot(data)
plt.title('Waveplot')
plt.xlabel('Time (samples)')
plt.ylabel('Amplitude')
plt.show()

# %%
audio_data_2d = audio_data_2d_predict('/content/drive/MyDrive/voice_clone/my_voice.mp3')
audio_data_2d
# Out:
# <ipython-input-1-1eb6edf7d723>:11: UserWarning: PySoundFile failed. Trying audioread instead.
#   X , sample_rate = librosa.load(file_name, sr=None) #Can also load file using librosa
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# array([[-3.07266663e+02,  1.94675766e+02, -2.61733437e+01,
#          7.12269497e+00,  3.63753929e+01, -1.14379156e+00,
#         -7.40026045e+00,  2.42026734e+00, -7.07772207e+00,
#         -5.60043812e+00, -3.02941251e+00, -1.04699211e+01,
#         -1.81126857e+00, -1.25183856e+00, -3.48239088e+00,
#          3.00291014e+00, -2.98497343e+00, -4.28697157e+00,
#          3.51249170e+00, -4.76686150e-01,  6.41692728e-02,
#          1.27632582e+00,  4.05328902e-02]])

# %%
mlp.predict(audio_data_2d)
# Out:
# 1/1 [==============================] - 0s 23ms/step
# array([[1.0000000e+00, 2.8590693e-13, 7.0094058e-25]], dtype=float32)

# %% [markdown]
# #### SVM Classification

# %% [markdown]
# - The C parammeter in SVM: https://stats.stackexchange.com/questions/31066/what-is-the-influence-of-c-in-svms-with-linear-kernel
# - What are C and gamma in SVM? https://www.quora.com/What-are-C-and-gamma-with-regards-to-a-support-vector-machine

# %%
#Load data from generated numpy files
X = np.load('feat.npy') # list of features
y = np.load('label.npy').ravel() # labels are the target

# %%
# coding= UTF-8
import numpy as np
import sklearn
from sklearn.svm import SVC, LinearSVC
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import reciprocal, uniform

#Load data from generated numpy files
X = np.load('feat.npy') # list of features
y = np.load('label.npy').ravel() # labels are the target

# Fix random seed number
np.random.seed(7)

# Load the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=30)
#Dr : 10 fold validation (9 train, 1 test), (8 train , 1 test, 1 train)
#Se entrena clasificador en un ciclo de 10 veces
#10 fold es parte de Sci-kit

# Data scaling (Do I need it?)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train.astype(np.float32))
X_test_scaled = scaler.transform(X_test.astype(np.float32))

# SVM classifier
svm_clf = SVC(C=200, gamma = 0.0001, kernel='rbf', decision_function_shape="ovr", probability = True)
#svm_clf = LinearSVC(random_state=42) # HandsOn git

# Fit model
svm_clf.fit(X_train, y_train) #From Beif github
#svm_clf.fit(X_train_scaled, y_train) # HandsOn book

# Predictions
y_predict = svm_clf.predict(X_test)

# Accuracy Result
acc = svm_clf.score(X_test, y_test) # From Beif github
print("Final accuracy = %0.4f" %acc)
#print('\n')
#print(classification_report(y_test, y_predict))
# Out:
# Final accuracy = 0.8972

# %%
svm_clf.predict(audio_data_2d)
# Out:
# array([1])

# %%
svm_clf.predict_proba(audio_data_2d)
# Out:
# array([[0.02423081, 0.89993312, 0.07583607]])

# %%
# View the predicted probabilities of the first n observations
svm_clf.predict_proba(X_test)[0:10] #IT IS NOT WORKING, CHECK LATER
# Out:
# array([[8.97227646e-03, 8.63554710e-04, 9.90164169e-01],
#        [5.43771013e-01, 4.37914988e-01, 1.83139996e-02],
#        [5.54423394e-01, 4.25149977e-01, 2.04266295e-02],
#        [3.55095740e-02, 3.79847962e-03, 9.60691946e-01],
#        [6.30604606e-03, 4.81547256e-03, 9.88878481e-01],
#        [2.07494185e-02, 1.62803820e-04, 9.79087778e-01],
#        [3.17291574e-02, 1.23324181e-02, 9.55938424e-01],
#        [9.40848305e-01, 5.19854150e-02, 7.16628024e-03],
#        [1.58346381e-02, 4.14906706e-02, 9.42674691e-01],
#        [1.27013995e-02, 9.87260126e-01, 3.84748549e-05]])

# %% [markdown]
# ##### Compute Confussion Matrix

# %%
# De-encoding predicted and actual classes (going from numeric to written)
prediction_decoded = label_classes[y_predict]
actual_value_decoded = label_classes[y_test]

# %%
## Confusion Matrix
# This is the unnormalized matrix ...
pd.crosstab(actual_value_decoded, prediction_decoded)
#pd.crosstab(test['species'], preds, rownames=['Actual Species'], colnames=['Predicted Species'])
# Out:
# col_0         High  Intermediate  Low
# row_0
# High           137             3    2
# Intermediate     1           132   26
# Low              1            11  115

# %% [markdown]
# #### Random Forest Classification (Sklearn)

# %% [markdown]
# - Tunning parameters of a RF: https://stackoverflow.com/questions/36107820/how-to-tune-parameters-in-random-forest-using-scikit-learn

# %%
from sklearn.ensemble import RandomForestClassifier #Random Forest classifier
import pandas as pd
import numpy as np
np.random.seed(7)

# %%
#Load data
X = np.load('feat.npy')
y = np.load('label.npy').ravel()


#Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=6)

# Initialize classifier
rf_clf = RandomForestClassifier(n_estimators=350, n_jobs=2, random_state=6, max_features="auto")

# Train model
rf_clf.fit(X_train, y_train)

# Make predictions
y_prediction = rf_clf.predict(X_test)

# Evaluate accuracy
acc = rf_clf.score(X_test, y_test)
print("Accuracy = %0.5f" %acc)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# Accuracy = 0.91121

# %%
# View the predicted probabilities of the first n observations
rf_clf.predict_proba(X_test)[0:10]
# Out:
# array([[0.        , 0.        , 1.        ],
#        [0.00285714, 0.00571429, 0.99142857],
#        [0.78285714, 0.07714286, 0.14      ],
#        [0.97142857, 0.00857143, 0.02      ],
#        [0.01428571, 0.98285714, 0.00285714],
#        [0.48571429, 0.48285714, 0.03142857],
#        [0.00571429, 0.01428571, 0.98      ],
#        [0.57142857, 0.31142857, 0.11714286],
#        [0.08857143, 0.15428571, 0.75714286],
#        [0.63714286, 0.31142857, 0.05142857]])

# %%
rf_clf.predict(audio_data_2d)
# Out:
# array([1])

# %%
rf_clf.predict_proba(audio_data_2d)
# Out:
# array([[0.14571429, 0.51142857, 0.34285714]])

# %% [markdown]
# ##### Compute Confussion Matrix

# %%
# De-encoding predicted and actual classes (going from numeric to written)
prediction_decoded = label_classes[y_prediction]
actual_value_decoded = label_classes[y_test]

## Confusion Matrix
pd.crosstab(actual_value_decoded, prediction_decoded)
# Out:
# col_0         High  Intermediate  Low
# row_0
# High           136             5    3
# Intermediate     1           136   19
# Low              1             9  118

# %% [markdown]
# #### CNN Classification (Keras Tensorflow)

# %%
# coding= UTF-8
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.layers import Embedding
from keras.layers import Conv1D, GlobalAveragePooling1D, MaxPooling1D
from keras.optimizers import SGD
from sklearn.model_selection import train_test_split

# Load data
X = np.load("feat.npy")
y = np.load('label.npy').ravel()

# Fix random seed number
np.random.seed(7)

number_of_features = len(X[1])
number_of_classes = 3

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 233)

# Need to reshape you data to have a spatial dimension for Conv1d to make sense
X_train = np.expand_dims(X_train, axis=2)
X_test = np.expand_dims(X_test, axis=2)

# Neural Network Construction
cnn = Sequential()

# Neural Network Architecture
# Using 1D Convolutions (approriate for audio files)

# first layer has 64 convolution filters
cnn.add(Conv1D(64, 3, activation='relu', padding='same', input_shape = (number_of_features, 1)))
cnn.add(Conv1D(64, 3, activation='relu'))
cnn.add(MaxPooling1D(3))
cnn.add(Conv1D(32, 3, padding='same', activation='relu'))
cnn.add(Conv1D(32, 3, padding='same', activation='relu'))
cnn.add(GlobalAveragePooling1D())
cnn.add(Dropout(0.5))

cnn.add(Dense(number_of_classes, activation='softmax'))

cnn.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# Convert label to onehot
y_train = keras.utils.to_categorical(y_train - 1, num_classes= number_of_classes) # Converts a class vector (integers) to binary class matrix
y_test = keras.utils.to_categorical(y_test - 1, num_classes= number_of_classes)

# Train Network
cnn.fit(X_train, y_train, batch_size=32, epochs=90)

# Evaluate model's accuracy with test data
score, acc = cnn.evaluate(X_test, y_test, batch_size=32) # Computes the loss & accuracy based on the input you pass it

print('Test score:', score) #loss
print('Test accuracy:', acc)
# Out:
# Epoch 1/90
# 32/32 [==============================] - 3s 13ms/step - loss: 1.2332 - accuracy: 0.4197
# Epoch 2/90
# 32/32 [==============================] - 0s 13ms/step - loss: 0.8845 - accuracy: 0.6054
# Epoch 3/90
# 32/32 [==============================] - 0s 13ms/step - loss: 0.7529 - accuracy: 0.6576
# Epoch 4/90
# 32/32 [==============================] - 0s 14ms/step - loss: 0.6663 - accuracy: 0.7129
# Epoch 5/90
# 32/32 [==============================] - 0s 15ms/step - loss: 0.6021 - accuracy: 0.7440
# Epoch 6/90
# 32/32 [==============================] - 0s 13ms/step - loss: 0.5834 - accuracy: 0.7500
# Epoch 7/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.4946 - accuracy: 0.7841
# Epoch 8/90
# 32/32 [==============================] - 0s 10ms/step - loss: 0.5277 - accuracy: 0.7821
# Epoch 9/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.4540 - accuracy: 0.8143
# Epoch 10/90
# 32/32 [==============================] - 1s 17ms/step - loss: 0.4229 - accuracy: 0.8112
# Epoch 11/90
# 32/32 [==============================] - 1s 18ms/step - loss: 0.4302 - accuracy: 0.8153
# Epoch 12/90
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3979 - accuracy: 0.8143
# Epoch 13/90
# 32/32 [==============================] - 1s 16ms/step - loss: 0.3827 - accuracy: 0.8434
# Epoch 14/90
# 32/32 [==============================] - 1s 16ms/step - loss: 0.3661 - accuracy: 0.8373
# Epoch 15/90
# 32/32 [==============================] - 0s 14ms/step - loss: 0.3546 - accuracy: 0.8584
# Epoch 16/90
# 32/32 [==============================] - 0s 15ms/step - loss: 0.3374 - accuracy: 0.8624
# Epoch 17/90
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3275 - accuracy: 0.8554
# Epoch 18/90
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3373 - accuracy: 0.8574
# Epoch 19/90
# 32/32 [==============================] - 1s 16ms/step - loss: 0.3097 - accuracy: 0.8685
# Epoch 20/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.2891 - accuracy: 0.8835
# Epoch 21/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.2967 - accuracy: 0.8685
# Epoch 22/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.2815 - accuracy: 0.8795
# Epoch 23/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.2618 - accuracy: 0.9026
# Epoch 24/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.2718 - accuracy: 0.8896
# Epoch 25/90
# 32/32 [==============================] - 0s 13ms/step - loss: 0.2537 - accuracy: 0.8986
# Epoch 26/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.2549 - accuracy: 0.8906
# Epoch 27/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.2401 - accuracy: 0.9066
# Epoch 28/90
# 32/32 [==============================] - 0s 13ms/step - loss: 0.2243 - accuracy: 0.9046
# Epoch 29/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.2272 - accuracy: 0.9036
# Epoch 30/90
# 32/32 [==============================] - 0s 13ms/step - loss: 0.2160 - accuracy: 0.9106
# Epoch 31/90
# 32/32 [==============================] - 0s 15ms/step - loss: 0.2126 - accuracy: 0.9177
# Epoch 32/90
# 32/32 [==============================] - 0s 14ms/step - loss: 0.2068 - accuracy: 0.9106
# Epoch 33/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1975 - accuracy: 0.9187
# Epoch 34/90
# 32/32 [==============================] - 0s 7ms/step - loss: 0.1863 - accuracy: 0.9187
# Epoch 35/90
# 32/32 [==============================] - 0s 8ms/step - loss: 0.1958 - accuracy: 0.9197
# Epoch 36/90
# 32/32 [==============================] - 0s 7ms/step - loss: 0.1844 - accuracy: 0.9227
# Epoch 37/90
# 32/32 [==============================] - 0s 7ms/step - loss: 0.1924 - accuracy: 0.9257
# Epoch 38/90
# 32/32 [==============================] - 0s 7ms/step - loss: 0.1794 - accuracy: 0.9347
# Epoch 39/90
# 32/32 [==============================] - 0s 8ms/step - loss: 0.1862 - accuracy: 0.9297
# Epoch 40/90
# 32/32 [==============================] - 0s 7ms/step - loss: 0.1686 - accuracy: 0.9418
# Epoch 41/90
# 32/32 [==============================] - 0s 7ms/step - loss: 0.1658 - accuracy: 0.9257
# Epoch 42/90
# 32/32 [==============================] - 0s 8ms/step - loss: 0.1544 - accuracy: 0.9357
# Epoch 43/90
# 32/32 [==============================] - 0s 7ms/step - loss: 0.1740 - accuracy: 0.9217
# Epoch 44/90
# 32/32 [==============================] - 0s 8ms/step - loss: 0.1541 - accuracy: 0.9408
# Epoch 45/90
# 32/32 [==============================] - 0s 7ms/step - loss: 0.1621 - accuracy: 0.9327
# Epoch 46/90
# 32/32 [==============================] - 0s 7ms/step - loss: 0.1538 - accuracy: 0.9398
# Epoch 47/90
# 32/32 [==============================] - 0s 8ms/step - loss: 0.1413 - accuracy: 0.9488
# Epoch 48/90
# 32/32 [==============================] - 0s 8ms/step - loss: 0.1372 - accuracy: 0.9498
# Epoch 49/90
# 32/32 [==============================] - 0s 7ms/step - loss: 0.1381 - accuracy: 0.9378
# Epoch 50/90
# 32/32 [==============================] - 0s 7ms/step - loss: 0.1415 - accuracy: 0.9398
# Epoch 51/90
# 32/32 [==============================] - 0s 9ms/step - loss: 0.1440 - accuracy: 0.9418
# Epoch 52/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1306 - accuracy: 0.9558
# Epoch 53/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1236 - accuracy: 0.9528
# Epoch 54/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1410 - accuracy: 0.9568
# Epoch 55/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1308 - accuracy: 0.9498
# Epoch 56/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1432 - accuracy: 0.9558
# Epoch 57/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1060 - accuracy: 0.9639
# Epoch 58/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1231 - accuracy: 0.9488
# Epoch 59/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1292 - accuracy: 0.9538
# Epoch 60/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0987 - accuracy: 0.9608
# Epoch 61/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1004 - accuracy: 0.9558
# Epoch 62/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0998 - accuracy: 0.9598
# Epoch 63/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1009 - accuracy: 0.9598
# Epoch 64/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1190 - accuracy: 0.9608
# Epoch 65/90
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0892 - accuracy: 0.9639
# Epoch 66/90
# 32/32 [==============================] - 0s 8ms/step - loss: 0.1345 - accuracy: 0.9528
# Epoch 67/90
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0999 - accuracy: 0.9719
# Epoch 68/90
# 32/32 [==============================] - 0s 7ms/step - loss: 0.1023 - accuracy: 0.9588
# Epoch 69/90
# 32/32 [==============================] - 0s 7ms/step - loss: 0.1160 - accuracy: 0.9608
# Epoch 70/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1112 - accuracy: 0.9578
# Epoch 71/90
# 32/32 [==============================] - 0s 14ms/step - loss: 0.1053 - accuracy: 0.9659
# Epoch 72/90
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0729 - accuracy: 0.9729
# Epoch 73/90
# 32/32 [==============================] - 0s 7ms/step - loss: 0.1078 - accuracy: 0.9659
# Epoch 74/90
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0991 - accuracy: 0.9598
# Epoch 75/90
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0921 - accuracy: 0.9699
# Epoch 76/90
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0775 - accuracy: 0.9729
# Epoch 77/90
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0805 - accuracy: 0.9659
# Epoch 78/90
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0702 - accuracy: 0.9729
# Epoch 79/90
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0734 - accuracy: 0.9719
# Epoch 80/90
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0921 - accuracy: 0.9568
# Epoch 81/90
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0871 - accuracy: 0.9649
# Epoch 82/90
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0686 - accuracy: 0.9729
# Epoch 83/90
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0780 - accuracy: 0.9679
# Epoch 84/90
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0934 - accuracy: 0.9699
# Epoch 85/90
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0695 - accuracy: 0.9809
# Epoch 86/90
# 32/32 [==============================] - 0s 7ms/step - loss: 0.1085 - accuracy: 0.9709
# Epoch 87/90
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0670 - accuracy: 0.9719
# Epoch 88/90
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0842 - accuracy: 0.9669
# Epoch 89/90
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0600 - accuracy: 0.9789
# Epoch 90/90
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0789 - accuracy: 0.9719
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4586 - accuracy: 0.9065
# Test score: 0.45864903926849365
# Test accuracy: 0.9065420627593994

# %%
cnn.predict(audio_data_2d)
# Out:
# 1/1 [==============================] - 0s 118ms/step
# array([[9.9079520e-01, 1.0344361e-08, 9.2047891e-03]], dtype=float32)

# %%
max(cnn.predict(audio_data_2d)[0])*100
# Out:
# 1/1 [==============================] - 0s 25ms/step
# 99.07951951026917

# %% [markdown]
# #### RNN Classification (Keras Tensorflow)

# %% [markdown]
# - Sigmoid vs Softmax: The sigmoid function is used for the two-class logistic regression (0 or 1, speech or non-speech), whereas the softmax function is used for the multiclass logistic regression (a.k.a. MaxEnt, multinomial logistic regression, softmax Regression, Maximum Entropy Classifier). (dog bark, sea waves, ...)
# - Network Architecture: Regarding more general choices, there is rarely a "right" way to construct the architecture. Instead that should be something you test with different meta-params (such as layer sizes, number of layers, amount of drop-out), and should be results-driven (including any limits you might have on resource use for training time/memory use etc).
# - https://datascience.stackexchange.com/questions/10048/what-is-the-best-keras-model-for-multi-class-classification

# %%
# coding= UTF-8
import os
import numpy as np
from sklearn.model_selection import train_test_split
import keras
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.optimizers import Adam

# Load data
X = np.load("feat.npy")
y = np.load('label.npy').ravel()

# Fix random seed number
np.random.seed(7)

number_of_features = len(X[1])
number_of_classes = 3

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 230)


# Reshape data for LSTM (Samples, Timesteps, Features)
X_train = np.expand_dims(X_train, axis=2) #(280,193,1)
X_test = np.expand_dims(X_test, axis=2)

y_train = keras.utils.to_categorical(y_train - 1, num_classes= number_of_classes) # Converts a class vector (integers) to binary class matrix
y_test = keras.utils.to_categorical(y_test - 1, num_classes= number_of_classes)

# Build RNN Neural Network
print('Build LSTM RNN model ...')
rnn = Sequential()
rnn.add(LSTM(256, return_sequences=True, input_shape=X_train.shape[1:]))
rnn.add(LSTM(32, return_sequences=False))

#model.add(LSTM(16, return_sequences=False))
rnn.add(Dense(number_of_classes, activation='softmax'))

print("Compiling ...")
rnn.compile(loss='categorical_crossentropy', # for multiple classes
              optimizer='rmsprop',
              metrics=['accuracy'])

print(rnn.summary())

print("Training ...")
rnn.fit(X_train, y_train, batch_size=64, epochs=60)

print("\nValidating ...")
score, accuracy = rnn.evaluate(X_test, y_test, batch_size=32, verbose=1)
print("Loss:  ", score)
print("Accuracy:  ", accuracy)
# Out:
# Build LSTM RNN model ...
# Compiling ...
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 23, 256)           264192
#
#  lstm_1 (LSTM)               (None, 32)                36992
#
#  dense_4 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 301,283
# Trainable params: 301,283
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training ...
# Epoch 1/60
# 16/16 [==============================] - 6s 168ms/step - loss: 1.0159 - accuracy: 0.5040
# Epoch 2/60
# 16/16 [==============================] - 3s 202ms/step - loss: 0.8710 - accuracy: 0.6014
# Epoch 3/60
# 16/16 [==============================] - 2s 128ms/step - loss: 0.7813 - accuracy: 0.6516
# Epoch 4/60
# 16/16 [==============================] - 2s 134ms/step - loss: 0.6982 - accuracy: 0.6777
# Epoch 5/60
# 16/16 [==============================] - 2s 135ms/step - loss: 0.6309 - accuracy: 0.7098
# Epoch 6/60
# 16/16 [==============================] - 2s 131ms/step - loss: 0.6087 - accuracy: 0.7239
# Epoch 7/60
# 16/16 [==============================] - 3s 158ms/step - loss: 0.5451 - accuracy: 0.7560
# Epoch 8/60
# 16/16 [==============================] - 3s 214ms/step - loss: 0.5465 - accuracy: 0.7570
# Epoch 9/60
# 16/16 [==============================] - 3s 176ms/step - loss: 0.4939 - accuracy: 0.7741
# Epoch 10/60
# 16/16 [==============================] - 2s 126ms/step - loss: 0.4691 - accuracy: 0.7992
# Epoch 11/60
# 16/16 [==============================] - 2s 126ms/step - loss: 0.4391 - accuracy: 0.8032
# Epoch 12/60
# 16/16 [==============================] - 2s 127ms/step - loss: 0.4412 - accuracy: 0.7952
# Epoch 13/60
# 16/16 [==============================] - 3s 159ms/step - loss: 0.4306 - accuracy: 0.8072
# Epoch 14/60
# 16/16 [==============================] - 3s 211ms/step - loss: 0.4086 - accuracy: 0.8112
# Epoch 15/60
# 16/16 [==============================] - 2s 125ms/step - loss: 0.3891 - accuracy: 0.8193
# Epoch 16/60
# 16/16 [==============================] - 2s 127ms/step - loss: 0.3759 - accuracy: 0.8283
# Epoch 17/60
# 16/16 [==============================] - 2s 127ms/step - loss: 0.3483 - accuracy: 0.8384
# Epoch 18/60
# 16/16 [==============================] - 2s 127ms/step - loss: 0.3811 - accuracy: 0.8213
# Epoch 19/60
# 16/16 [==============================] - 2s 135ms/step - loss: 0.3394 - accuracy: 0.8524
# Epoch 20/60
# 16/16 [==============================] - 3s 214ms/step - loss: 0.3329 - accuracy: 0.8444
# Epoch 21/60
# 16/16 [==============================] - 3s 158ms/step - loss: 0.3405 - accuracy: 0.8534
# Epoch 22/60
# 16/16 [==============================] - 2s 129ms/step - loss: 0.3069 - accuracy: 0.8685
# Epoch 23/60
# 16/16 [==============================] - 2s 125ms/step - loss: 0.2965 - accuracy: 0.8675
# Epoch 24/60
# 16/16 [==============================] - 2s 130ms/step - loss: 0.2930 - accuracy: 0.8705
# Epoch 25/60
# 16/16 [==============================] - 2s 128ms/step - loss: 0.2973 - accuracy: 0.8775
# Epoch 26/60
# 16/16 [==============================] - 3s 196ms/step - loss: 0.2447 - accuracy: 0.8886
# Epoch 27/60
# 16/16 [==============================] - 3s 179ms/step - loss: 0.2939 - accuracy: 0.8906
# Epoch 28/60
# 16/16 [==============================] - 2s 127ms/step - loss: 0.2747 - accuracy: 0.8795
# Epoch 29/60
# 16/16 [==============================] - 2s 128ms/step - loss: 0.2431 - accuracy: 0.9016
# Epoch 30/60
# 16/16 [==============================] - 2s 130ms/step - loss: 0.2633 - accuracy: 0.8855
# Epoch 31/60
# 16/16 [==============================] - 2s 128ms/step - loss: 0.2295 - accuracy: 0.9006
# Epoch 32/60
# 16/16 [==============================] - 3s 177ms/step - loss: 0.2331 - accuracy: 0.9026
# Epoch 33/60
# 16/16 [==============================] - 3s 207ms/step - loss: 0.2306 - accuracy: 0.9006
# Epoch 34/60
# 16/16 [==============================] - 2s 131ms/step - loss: 0.2046 - accuracy: 0.9187
# Epoch 35/60
# 16/16 [==============================] - 2s 127ms/step - loss: 0.2172 - accuracy: 0.9076
# Epoch 36/60
# 16/16 [==============================] - 2s 128ms/step - loss: 0.2335 - accuracy: 0.9076
# Epoch 37/60
# 16/16 [==============================] - 2s 129ms/step - loss: 0.1766 - accuracy: 0.9277
# Epoch 38/60
# 16/16 [==============================] - 2s 147ms/step - loss: 0.2128 - accuracy: 0.9106
# Epoch 39/60
# 16/16 [==============================] - 3s 213ms/step - loss: 0.1875 - accuracy: 0.9257
# Epoch 40/60
# 16/16 [==============================] - 2s 142ms/step - loss: 0.1664 - accuracy: 0.9287
# Epoch 41/60
# 16/16 [==============================] - 2s 130ms/step - loss: 0.1798 - accuracy: 0.9307
# Epoch 42/60
# 16/16 [==============================] - 2s 130ms/step - loss: 0.1539 - accuracy: 0.9378
# Epoch 43/60
# 16/16 [==============================] - 2s 128ms/step - loss: 0.1632 - accuracy: 0.9277
# Epoch 44/60
# 16/16 [==============================] - 2s 127ms/step - loss: 0.1546 - accuracy: 0.9438
# Epoch 45/60
# 16/16 [==============================] - 3s 211ms/step - loss: 0.1852 - accuracy: 0.9237
# Epoch 46/60
# 16/16 [==============================] - 3s 161ms/step - loss: 0.1277 - accuracy: 0.9478
# Epoch 47/60
# 16/16 [==============================] - 2s 125ms/step - loss: 0.1530 - accuracy: 0.9367
# Epoch 48/60
# 16/16 [==============================] - 2s 128ms/step - loss: 0.1483 - accuracy: 0.9357
# Epoch 49/60
# 16/16 [==============================] - 2s 129ms/step - loss: 0.1375 - accuracy: 0.9378
# Epoch 50/60
# 16/16 [==============================] - 2s 126ms/step - loss: 0.1423 - accuracy: 0.9357
# Epoch 51/60
# 16/16 [==============================] - 3s 179ms/step - loss: 0.1266 - accuracy: 0.9458
# Epoch 52/60
# 16/16 [==============================] - 3s 192ms/step - loss: 0.1352 - accuracy: 0.9438
# Epoch 53/60
# 16/16 [==============================] - 2s 126ms/step - loss: 0.1197 - accuracy: 0.9518
# Epoch 54/60
# 16/16 [==============================] - 2s 125ms/step - loss: 0.1059 - accuracy: 0.9598
# Epoch 55/60
# 16/16 [==============================] - 2s 125ms/step - loss: 0.1264 - accuracy: 0.9518
# Epoch 56/60
# 16/16 [==============================] - 2s 126ms/step - loss: 0.1202 - accuracy: 0.9538
# Epoch 57/60
# 16/16 [==============================] - 2s 150ms/step - loss: 0.0991 - accuracy: 0.9568
# Epoch 58/60
# 16/16 [==============================] - 3s 212ms/step - loss: 0.1091 - accuracy: 0.9608
# Epoch 59/60
# 16/16 [==============================] - 2s 142ms/step - loss: 0.1184 - accuracy: 0.9498
# Epoch 60/60
# 16/16 [==============================] - 3s 195ms/step - loss: 0.0854 - accuracy: 0.9689
#
# Validating ...
# 14/14 [==============================] - 2s 33ms/step - loss: 0.5360 - accuracy: 0.8271
# Loss:   0.5359828472137451
# Accuracy:   0.827102780342102

# %%
rnn.predict(audio_data_2d)
# Out:
# 1/1 [==============================] - 1s 831ms/step
# array([[0.8505195 , 0.0101659 , 0.13931467]], dtype=float32)
